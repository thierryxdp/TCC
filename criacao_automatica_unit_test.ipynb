# %% [markdown]
# ## Template
#
# Vou te passar testes em pytest para um problema de programação em python sobre o tema (Tema do Capítulo). Em seguida te passarei o contexto do problema e a solução. Quero que você use os meus testes, aqueles que forneci, mas altere TODOS os parâmetros para valores que fazem sentido no problema dado, apenas valores que aparecem no problema real. No final, refaça os testes redundantes, ou seja, se um teste tiver a mesma entrada e a mesma saída que outro teste, altere os valores de um dos testes.
#
# Meus Testes:
# (Testes)
#
#
# Contexto do Problema:
# (Problema)
#
#
# Solução do problema em python:
# (Solução)

# %% [markdown]
# ## Teste 1 - Problema 794 - Busca de Funcionários

# %%
tests = !crosshair cover --example_output_format=pytest --coverage_type=path solucao.busca_com_tipo --per_condition_timeout=100
for t in tests:   
    print(t)
# Out:
# import pytest
# from solucao import busca_com_tipo
#
# def test_busca_com_tipo():
#     assert busca_com_tipo('', [[0, 0, '', '']]) == [[0, 0, '']]
#
# def test_busca_com_tipo_2():
#     assert busca_com_tipo('', []) == 'Nenhum registro encontrado'
#
# def test_busca_com_tipo_3():
#     assert busca_com_tipo('-', [['', '', ''], [0, 0, '']]) == 'Nenhum registro encontrado'
#
# def test_busca_com_tipo_4():
#     assert busca_com_tipo('ŀ', [[0, '', '', 0, ''], [0, '', '', 0, '']]) == 'Nenhum registro encontrado'
#
# def test_busca_com_tipo_5():
#     with pytest.raises(IndexError):
#         busca_com_tipo('', [[]])
#
# def test_busca_com_tipo_6():
#     assert busca_com_tipo('ł', [[['', '', '\x00'], '\x00', ''], ['', '', '\x00'], ['', ['', '', '\x00'], '\x00']]) == 'Nenhum registro encontrado'
#
# def test_busca_com_tipo_7():
#     assert busca_com_tipo('ŋ', [['', 0, ''], ['', '', ''], [[['', '', ''], 0, ''], '', '', 0], [['', '', ''], 0, '']]) == 'Nenhum registro encontrado'
#
# ...

# %% [markdown]
# ### Usando Template no Chat GPT.
#
# ### Texto Enviado:
#
# Vou te passar testes em pytest para um problema de programação em python sobre o tema laços aninhados e matrizes. Em seguida te passarei o contexto do problema e a solução. Quero que você use os meus testes, aqueles que forneci, mas altere TODOS os parâmetros para valores que fazem sentido no problema dado, apenas valores que aparecem no problema real. No final, refaça os testes redundantes, ou seja, se um teste tiver a mesma entrada e a mesma saída que outro teste, altere os valores de um dos testes.
#
# def test_busca_com_tipo():
#     assert busca_com_tipo("", [[0, 0, "", ""]]) == [[0, 0, ""]]
#
# def test_busca_com_tipo_2():
#     assert busca_com_tipo("", []) == "Nenhum registro encontrado"
#
# def test_busca_com_tipo_3():
#     assert busca_com_tipo("ĥ", [["", "", ""], [0, 0, ""]]) == "Nenhum registro encontrado"
#
# def test_busca_com_tipo_4():
#     assert busca_com_tipo("-", [[0, "", "", 0, ""], [0, "", "", 0, ""]]) == "Nenhum registro encontrado"
#
# def test_busca_com_tipo_5():
#     with pytest.raises(IndexError):
#         busca_com_tipo("", [[]])
#
# def test_busca_com_tipo_6():
#     assert busca_com_tipo("ŗ", [[["", "", "\x00"], "\x00", ""], ["", "", "\x00"], ["", ["", "", "\x00"], "\x00"]]) == "Nenhum registro encontrado"
#
# def test_busca_com_tipo_7():
#     assert busca_com_tipo("ć", [["", 0, ""], ["", "", ""], [[["", "", ""], 0, ""], "", "", 0], [["", "", ""], 0, ""]]) == "Nenhum registro encontrado"
#
# def test_busca_com_tipo_8():
#     with pytest.raises(IndexError):
#         busca_com_tipo("", [[0, "", ""]])
#
# def test_busca_com_tipo_9():
#     assert busca_com_tipo("", [[0, 0, "\x00"]]) == "Nenhum registro encontrado"
#
# def test_busca_com_tipo_10():
#     assert busca_com_tipo("", [["", "", "", ""]]) == [["", "", ""]]
#
# def test_busca_com_tipo_11():
#     with pytest.raises(IndexError):
#         busca_com_tipo("", [[0, [], "\x00", "", "\x00"], [[], [], "\x00"], [], []])
#
# def test_busca_com_tipo_12():
#     with pytest.raises(IndexError):
#         busca_com_tipo("ş", [[0, 0, ""], [0, 0, ""], [], [0, [0, 0, ""]]])
#
# def test_busca_com_tipo_13():
#     with pytest.raises(IndexError):
#         busca_com_tipo("", [["", [], "", ""], [], []])
#
# def test_busca_com_tipo_14():
#     assert busca_com_tipo("", [["", "", "", ""], [0, "", "\x00"]]) == [["", "", ""]]
#
# def test_busca_com_tipo_15():
#     assert busca_com_tipo("\x00", [["\x01", "", ""], ["", "", "\x01"]]) == "Nenhum registro encontrado"
#
# def test_busca_com_tipo_16():
#     with pytest.raises(IndexError):
#         busca_com_tipo("ė", [["", 0, ""], ["", [], "\x00", ["", 0, "", "", ""]], ["", 0, "", "", ""], []])
#
# def test_busca_com_tipo_17():
#     assert busca_com_tipo("", [[0, "", 0]]) == "Nenhum registro encontrado"
#
# def test_busca_com_tipo_18():
#     assert busca_com_tipo("İ", [["", "", ""], ["\x00", "\x00", "\x00"]]) == "Nenhum registro encontrado"
#
# Contexto do Problema:
# Para o seguinte problema inicial de programação sobre o tema laços aninhados e matrizes:
# Suponha que os dados de funcionários de uma empresa sejam armazenados em uma matriz como a do exemplo a seguir:
#
# Cada linha da matriz tem quatro entradas, representando as informações referentes a nome, registro, setor e telefone de um funcionário, nesta ordem. O número de linhas depende da quantidade de funcionários. Todas as entradas da matriz estão em formato string.
#
# Escreva uma função chamada **busca** que receba uma matriz como a do exemplo e faça uma busca por setor, ou seja, dado um nome de um setor da empresa, a função retorna os dados de todos os funcionários daquele setor. Por exemplo:
#
# >>> busca("Contabilidade", matriz)
#
# >>> [[‘Adalberto Ferreira’, ‘566’, ‘(21)84564-5248’],[‘Flavia Amorim’, ‘465’, ‘(21)2134-4845"]]
#
# Se nenhum registro for encontrado, a função deverá retornar uma lista vazia.
#
# Solução do problema em python:
# def busca_com_tipo(setor: str, matriz: list[list]) -> list[list]:
#     result = []
#     for line in matriz:
#         if (line[2] == setor):
#             result.append(line[0:2] + [line[3]])
#
#     if(len(result) == 0):
#         return "Nenhum registro encontrado"
#
#     return result

# %% [markdown]
# ### Reposta Chat GPT

# %%
def test_busca_com_tipo_1():
    matriz = [
        ["Adalberto Ferreira", "566", "Contabilidade", "(21)84564-5248"],
        ["Flavia Amorim", "465", "Contabilidade", "(21)2134-4845"]
    ]
    assert busca_com_tipo("Contabilidade", matriz) == [
        ["Adalberto Ferreira", "566", "(21)84564-5248"],
        ["Flavia Amorim", "465", "(21)2134-4845"]
    ]

def test_busca_com_tipo_2():
    matriz = [
        ["Marcos Silva", "123", "RH", "(21)98765-4321"],
        ["Lucia Mendes", "789", "RH", "(21)1234-5678"]
    ]
    assert busca_com_tipo("RH", matriz) == [
        ["Marcos Silva", "123", "(21)98765-4321"],
        ["Lucia Mendes", "789", "(21)1234-5678"]
    ]

def test_busca_com_tipo_3():
    matriz = [
        ["Carlos Santos", "111", "TI", "(21)5555-5555"]
    ]
    assert busca_com_tipo("TI", matriz) == [
        ["Carlos Santos", "111", "(21)5555-5555"]
    ]

def test_busca_com_tipo_4():
    matriz = [
        ["Ana Rodrigues", "222", "Marketing", "(21)7777-7777"],
        ["Paulo Oliveira", "333", "Marketing", "(21)8888-8888"]
    ]
    assert busca_com_tipo("Marketing", matriz) == [
        ["Ana Rodrigues", "222", "(21)7777-7777"],
        ["Paulo Oliveira", "333", "(21)8888-8888"]
    ]

def test_busca_com_tipo_5():
    matriz = [
        ["Joao Pereira", "444", "Vendas", "(21)9999-9999"]
    ]
    assert busca_com_tipo("Vendas", matriz) == [
        ["Joao Pereira", "444", "(21)9999-9999"]
    ]

def test_busca_com_tipo_6():
    matriz = []
    assert busca_com_tipo("Financeiro", matriz) == "Nenhum registro encontrado"

def test_busca_com_tipo_7():
    matriz = [
        ["Maria Silva", "555", "Logistica", "(21)6666-6666"],
        ["Pedro Almeida", "777", "Logistica", "(21)3333-3333"]
    ]
    assert busca_com_tipo("Logistica", matriz) == [
        ["Maria Silva", "555", "(21)6666-6666"],
        ["Pedro Almeida", "777", "(21)3333-3333"]
    ]

# %% [markdown]
# ## Teste 2 - Problema 749 - Número de Dias

# %%
tests = !crosshair cover --example_output_format=pytest --coverage_type=path solucao.diff_datas_com_tipo --per_condition_timeout=100

# %%
realtests = []
begin_test = 0
test = tests[2]
for i in range(3, len(tests)):
    if 'test_' in tests[i]:
        realtests.append(test)
        test = tests[i]
    else:
        test += tests[i]

for rt in realtests:
    if 'pytest.raises' not in rt:
        print(rt)
# Out:
# def test_diff_datas_com_tipo():    assert diff_datas_com_tipo('00\x0000\x000000', '00\x0000\x000000') == 0
# def test_diff_datas_com_tipo_75():    assert diff_datas_com_tipo('00\x0000\x000', '00\x0000\x000') == 0
# def test_diff_datas_com_tipo_322():    assert diff_datas_com_tipo('00\x0000\x000000', '00\x0000\x000') == 0
# def test_diff_datas_com_tipo_360():    assert diff_datas_com_tipo('00\x000\t\x000', '00\x0000\x000') == 0
# def test_diff_datas_com_tipo_390():    assert diff_datas_com_tipo('00\x0000\x000', '00\x0000\x000000') == 0
# def test_diff_datas_com_tipo_450():    assert diff_datas_com_tipo('00\x0000\x000', '00\x000\t\x000') == 0
# def test_diff_datas_com_tipo_512():    assert diff_datas_com_tipo('0\t\x0000\x000', '00\x0000\x000') == 0
# def test_diff_datas_com_tipo_513():    assert diff_datas_com_tipo('0\n\x0000\x000', '00\x0000\x000') == 0
# def test_diff_datas_com_tipo_514():    assert diff_datas_com_tipo('0\x0b\x0000\x000', '00\x0000\x000') == 0
# ...

# %% [markdown]
# ### Usando Template no Chat GPT.
#
# ### Texto Enviado:
#
# Vou te passar testes em pytest para um problema de programação em python sobre o tema variáveis e atribuição, strings. Em seguida te passarei o contexto do problema e a solução. Quero que você use os meus testes, aqueles que forneci, mas altere TODOS os parâmetros para valores que fazem sentido no problema dado, apenas valores que aparecem no problema real. No final, refaça os testes redundantes, ou seja, se um teste tiver a mesma entrada e a mesma saída que outro teste, altere os valores de um dos testes.
#
# def test_diff_datas_com_tipo():    assert diff_datas_com_tipo('00\x0000\x000000', '00\x0000\x000000') == 0
# def test_diff_datas_com_tipo_75():    assert diff_datas_com_tipo('00\x0000\x000', '00\x0000\x000') == 0
# def test_diff_datas_com_tipo_322():    assert diff_datas_com_tipo('00\x0000\x000000', '00\x0000\x000') == 0
# def test_diff_datas_com_tipo_360():    assert diff_datas_com_tipo('00\x000\t\x000', '00\x0000\x000') == 0
# def test_diff_datas_com_tipo_390():    assert diff_datas_com_tipo('00\x0000\x000', '00\x0000\x000000') == 0
# def test_diff_datas_com_tipo_450():    assert diff_datas_com_tipo('00\x0000\x000', '00\x000\t\x000') == 0
# def test_diff_datas_com_tipo_512():    assert diff_datas_com_tipo('0\t\x0000\x000', '00\x0000\x000') == 0
# def test_diff_datas_com_tipo_513():    assert diff_datas_com_tipo('0\n\x0000\x000', '00\x0000\x000') == 0
# def test_diff_datas_com_tipo_514():    assert diff_datas_com_tipo('0\x0b\x0000\x000', '00\x0000\x000') == 0
# def test_diff_datas_com_tipo_566():    assert diff_datas_com_tipo('0\x0c\x0000\x000', '00\x0000\x000') == 0
# def test_diff_datas_com_tipo_603():    assert diff_datas_com_tipo('0\r\x0000\x000', '00\x0000\x000') == 0
# def test_diff_datas_com_tipo_689():    assert diff_datas_com_tipo('00\x0000\x000', '0\t\x0000\x000') == 0
#
# Contexto do Problema:
# Escreva uma função chamada diff_datas  que receba duas datas no formato ”DD/MM/AAAA”, sendo a segunda maior que a primeira, e calcule o total de dias passados entre uma data e outra. Retorne o total de dias encontrado. Considere que todo mês tem 30 dias. E que o ano tem 365 dias. Exemplo: Se as datas são ”02/03/1982” e ”01/02/1983”, o total de dias é 334. Como estamos considerando que todo mês tem 30 dias, a resposta final será aproximada e não será realmente a diferença de dias entre as duas datas.
# Dica: Preste atenção quando o dia ou mês da segunda data for menor que o da primeira. Não basta fazer somente a diferença entre eles!!
#
# Solução do problema em python:
# def diff_datas(data1: str, data2:str) -> int:
#     return 365*(int(data2[6:10]) - int(data1[6:10])) + 30*(int(data2[3:5]) - int(data1[3:5])) + int(data2[0:2]) - int(data1[0:2])

# %% [markdown]
# ### Reposta Chat GPT

# %%
def test_diff_datas_1():
    assert diff_datas("01/01/2000", "01/01/2000") == 0

def test_diff_datas_2():
    assert diff_datas("01/01/2000", "01/02/2000") == 30

def test_diff_datas_3():
    assert diff_datas("01/02/2000", "01/01/2001") == 334

def test_diff_datas_4():
    assert diff_datas("01/01/2022", "01/01/2023") == 365

def test_diff_datas_5():
    assert diff_datas("02/03/1982", "01/02/1983") == 334

def test_diff_datas_6():
    assert diff_datas("01/01/2000", "31/12/2000") == 364

def test_diff_datas_7():
    assert diff_datas("01/01/2000", "31/01/2000") == 30

def test_diff_datas_8():
    assert diff_datas("01/01/2000", "28/02/2000") == 58

def test_diff_datas_9():
    assert diff_datas("01/01/2000", "29/02/2000") == 59

def test_diff_datas_10():
    assert diff_datas("01/01/2000", "30/12/2000") == 364

def test_diff_datas_11():
    assert diff_datas("01/01/2000", "31/01/2001") == 395

def test_diff_datas_12():
    assert diff_datas("01/01/2000", "01/01/2100") == 36524

def test_diff_datas_13():
    assert diff_datas("01/01/2000", "01/01/2200") == 73049

def test_diff_datas_14():
    assert diff_datas("01/01/2000", "01/01/2400") == 109574

def test_diff_datas_15():
    assert diff_datas("01/01/2000", "01/01/2800") == 146099

def test_diff_datas_16():
    assert diff_datas("01/01/2000", "01/01/3200") == 182624

# %% [markdown]
# ### Reposta Chat GPT Sem Passar os Testes

# %%
def test_busca_com_tipo():
    matriz = [['Adalberto Ferreira', '566', 'Contabilidade', '(21)84564-5248'],
              ['Flavia Amorim', '465', 'Contabilidade', '(21)2134-4845'],
              ['José Silva', '789', 'RH', '(21)9876-5432'],
              ['Maria Souza', '123', 'TI', '(21)1234-5678']]
    
    # Teste 1: Procurar por funcionários no setor "Contabilidade"
    resultado = busca_com_tipo("Contabilidade", matriz)
    expected_result = [['Adalberto Ferreira', '566', '(21)84564-5248'], ['Flavia Amorim', '465', '(21)2134-4845']]
    assert resultado == expected_result, f"Erro no Teste 1. Resultado: {resultado}"

    # Teste 2: Procurar por funcionários no setor "RH"
    resultado = busca_com_tipo("RH", matriz)
    expected_result = [['José Silva', '789', '(21)9876-5432']]
    assert resultado == expected_result, f"Erro no Teste 2. Resultado: {resultado}"

    # Teste 3: Procurar por funcionários no setor "TI"
    resultado = busca_com_tipo("TI", matriz)
    expected_result = [['Maria Souza', '123', '(21)1234-5678']]
    assert resultado == expected_result, f"Erro no Teste 3. Resultado: {resultado}"

    # Teste 4: Procurar por funcionários no setor "Vendas" (nenhum registro encontrado)
    resultado = busca_com_tipo("Vendas", matriz)
    expected_result = "Nenhum registro encontrado"
    assert resultado == expected_result, f"Erro no Teste 4. Resultado: {resultado}"

    # Teste 5: Procurar por funcionários no setor "Marketing" (nenhum registro encontrado)
    resultado = busca_com_tipo("Marketing", matriz)
    expected_result = "Nenhum registro encontrado"
    assert resultado == expected_result, f"Erro no Teste 5. Resultado: {resultado}"

if __name__ == "__main__":
    test_busca_com_tipo()
    print("Todos os testes passaram com sucesso.")

# %%
def test_diff_datas():
    # Teste 1: Diferença entre 02/03/1982 e 01/02/1983 (365 dias + 30 dias + 1 dia = 396 dias)
    resultado = diff_datas("02/03/1982", "01/02/1983")
    expected_result = 396
    assert resultado == expected_result, f"Erro no Teste 1. Resultado: {resultado}"

    # Teste 2: Diferença entre 10/12/2000 e 15/12/2000 (5 dias)
    resultado = diff_datas("10/12/2000", "15/12/2000")
    expected_result = 5
    assert resultado == expected_result, f"Erro no Teste 2. Resultado: {resultado}"

    # Teste 3: Diferença entre 01/01/2000 e 01/01/2000 (0 dias)
    resultado = diff_datas("01/01/2000", "01/01/2000")
    expected_result = 0
    assert resultado == expected_result, f"Erro no Teste 3. Resultado: {resultado}"

    # Teste 4: Diferença entre 01/01/2022 e 31/12/2021 (365 dias)
    resultado = diff_datas("01/01/2022", "31/12/2021")
    expected_result = 365
    assert resultado == expected_result, f"Erro no Teste 4. Resultado: {resultado}"

    # Teste 5: Diferença entre 31/12/2022 e 01/01/2023 (1 dia)
    resultado = diff_datas("31/12/2022", "01/01/2023")
    expected_result = 1
    assert resultado == expected_result, f"Erro no Teste 5. Resultado: {resultado}"

if __name__ == "__main__":
    test_diff_datas()
    print("Todos os testes passaram com sucesso.")
